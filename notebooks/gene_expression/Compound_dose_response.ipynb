# %% [markdown]
# <a href="https://colab.research.google.com/github/cmap/lincs-workshop-2020/blob/main/notebooks/gene_expression/Compound_dose_response.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Compound Dose Response Example

# %% [markdown]
# The goal of this exercise is to try to assess the different types of dose behavior we observe in L1000 data. As a case study, we'll be using signatures of ~1,500 compounds profiled at 6-point dose across multiple cell lines. It is worth noting that the previous version of the CMap L1000 resource was mostly done at 1 dose, but the recent expansion includes thousands of compounds profiled at dose.

# %% [markdown]
# # Setup, read in data

# %% [markdown]
# We'll obtain the data using the cmapBQ toolkit, demonstrated in an separate notebook. The steps below will install and configure the toolkit so that we can retrieve the signature metadata of interest.

# %%
# !pip -q install cmapBQ
# Out:
#      |████████████████████████████████| 153kB 12.7MB/s

# %%
import requests

# URL with credentials
url = ('https://s3.amazonaws.com/data.clue.io/api/bq_creds/BQ-demo-credentials.json')

response = requests.get(url)
credentials_filepath='/content/BQ-demo-credentials.json'

with open(credentials_filepath, 'w') as f:
  f.write(response.text)

# %%
import cmapBQ.query as cmap_query
import cmapBQ.config as cmap_config

# Set up credentials
cmap_config.setup_credentials(credentials_filepath)
bq_client = cmap_config.get_bq_client()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
from __future__ import division
% matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

# %% [markdown]
# For simplicity, the data we'll use here is will meet the following criteria:
# * 24H
# * most common dose series: 10 uM -> 40 nM in 3-fold dilutions

# %%
sql = """
SELECT sig_id, pert_id, cmap_name, pert_dose, pert_idose,
pert_itime, cell_iname, nsample, tas FROM
cmap-big-table.cmap_lincs_public_views.siginfo WHERE
sig_id like 'REP.A%' AND
pert_type = 'trt_cp' AND
nsample > 1 AND
pert_itime = '24 h'
"""

# %%
siginfo = cmap_query.run_query(query=sql, client=bq_client).result().to_dataframe()

# %%
siginfo.head()
# Out:
#                     sig_id        pert_id       cmap_name  pert_dose  \
# 0    REP.A013_HA1E_24H:G12  BRD-K40227168      vinburnine   0.027958
# 1  REP.A010_HEK293_24H:J09  BRD-K13819402  desoxypeganine   1.064860
# 2    REP.A027_THP1_24H:A12  BRD-K92301463   BRD-K92301463   0.004115
# 3     REP.A018_PC3_24H:A22  BRD-K62277907       PYM-50028   0.177791
# 4    REP.A006_HT29_24H:K17  BRD-A22380646    pantoprazole   0.124069
#
#   pert_idose pert_itime cell_iname  nsample       tas
# 0    0.03 uM       24 h       HA1E        3  0.140143
# 1    1.11 uM       24 h     HEK293        3  0.096059
# 2   0.004 uM       24 h       THP1        2  0.138375
# 3     0.2 uM       24 h        PC3        3  0.211388
# 4   0.125 uM       24 h       HT29        3  0.252974

# %%
# count the number of occurrences at each dose
siginfo.pert_idose.value_counts()
# Out:
# 0.04 uM     16820
# 0.37 uM     16769
# 1.11 uM     16759
# 3.33 uM     16747
# 0.125 uM    16671
# 10 uM       16578
# 20 uM        5772
# 0.12 uM        81
# 0.3 uM         68
# 0.01 uM        66
# 4 uM           64
# 0.004 uM       57
# 1.25 uM        53
# 0.05 uM        40
# 0.02 uM        38
# 0.5 uM         38
# 1.67 uM        36
# 12 uM          25
# 0.2 uM         24
# 0.06 uM        24
# 6.66 uM        24
# 0.03 uM        23
# 0.74 uM        23
# 2.22 uM        21
# 0.66 uM        21
# 0.025 uM       21
# 0.22 uM        21
# 0.07 uM        21
# 0.08 uM        12
# 0.25 uM        12
# 2.5 uM         11
# 8 uM           11
# Name: pert_idose, dtype: int64

# %% [markdown]
# That looks pretty decent but there are some signatures that don't fall within the expected dose range. We can clean that up by restricting to a specific list of doses.

# %%
# what are the allowed doses
allowed_doses = ['0.04 uM', '0.125 uM', '0.37 uM', '1.11 uM', '3.33 uM', '10 uM']

# %%
siginfo = siginfo[siginfo.pert_idose.isin(allowed_doses)]
siginfo.pert_idose.value_counts()
# Out:
# 0.04 uM     16820
# 0.37 uM     16769
# 1.11 uM     16759
# 3.33 uM     16747
# 0.125 uM    16671
# 10 uM       16578
# Name: pert_idose, dtype: int64

# %% [markdown]
# # Let's take a look at the data

# %% [markdown]
# How many total signatures are we working with?

# %%
len(siginfo)
# Out:
# 100344

# %% [markdown]
# How many compounds?

# %%
cp_list = siginfo["cmap_name"].unique()
len(cp_list)
# Out:
# 1561

# %% [markdown]
# Signatures per cell line?

# %%
siginfo["cell_iname"].value_counts()
# Out:
# MCF7        9288
# HT29        9277
# A375        8949
# HA1E        8933
# PC3         8925
# YAPC        8924
# HELA        8609
# A549        7589
# MCF10A      6565
# HEK293      5902
# MDAMB231    5261
# THP1        4883
# JURKAT      4241
# XC.L10      1667
# HUVEC       1331
# Name: cell_iname, dtype: int64

# %%
siginfo.nsample.value_counts()
# Out:
# 3    77335
# 2    23009
# Name: nsample, dtype: int64

# %% [markdown]
# # Global Trends

# %% [markdown]
# Let's start by seeing if we see a dose response in TAS, even when aggregated across compounds and cell lines.
#
# We would expect increasing TAS with increasing dose:

# %%
sns.boxplot(x="pert_idose",
            y="tas",
            data=siginfo,
            order=allowed_doses);

# %% [markdown]
# What if we split by cell line?

# %%
f, ax = plt.subplots(figsize=(10,7))
sns.boxplot(x="cell_iname",
            y="tas",
            hue="pert_idose",
            data=siginfo,
            hue_order=allowed_doses)
plt.legend(bbox_to_anchor=(1.17,1), loc="upper right");
plt.xticks(rotation=45);

# %% [markdown]
# # Per compound

# %% [markdown]
# Now we'll take a look at dose response at the compound level. Let's keep things aggregated by cell line for now.

# %% [markdown]
# Let's take a look at a few compounds that might fall into some categories

# %% [markdown]
# ### Dose-responsive: AZD-5438

# %%
cp = "AZD-5438"
cp_subset = siginfo[siginfo["cmap_name"] == cp]

f,ax = plt.subplots()
sns.boxplot(x="pert_idose",
            y="tas",
            data=cp_subset,
            order=allowed_doses);
plt.title(cp);
plt.ylim(0,1);
ax.axhline(0.2, color="red", linestyle="dotted");

# %% [markdown]
# ### Saturated: bortezomib

# %%
cp = "bortezomib"
cp_subset = siginfo[siginfo["cmap_name"] == cp]

f,ax = plt.subplots()
sns.boxplot(x="pert_idose",
            y="tas",
            data=cp_subset,
            order=allowed_doses);
plt.title(cp);
plt.ylim(0,1);
ax.axhline(0.2, color="red", linestyle="dotted");

# %% [markdown]
# ### Inert: ibudilast

# %%
cp = "ibudilast"
cp_subset = siginfo[siginfo["cmap_name"] == cp]

f,ax = plt.subplots()
sns.boxplot(x="pert_idose",
            y="tas",
            data=cp_subset,
            order=allowed_doses);
plt.title(cp);
plt.ylim(0,1);
ax.axhline(0.2, color="red", linestyle="dotted");

# %% [markdown]
# # Per compound, cell line

# %% [markdown]
# For some compounds, it looks like we can get at how dose-responsive they are even when aggregated across cell lines. But by aggregating, we won't see activity differences by cell line.
#
# So let's take a deeper, unaggregated look at those compounds from above.

# %%
cp = "AZD-5438"
cp_subset = siginfo[siginfo["cmap_name"] == cp].dropna(subset=["tas"])

f, ax = plt.subplots(figsize=(10,7))
sns.pointplot(x="pert_idose",
            y="tas",
            hue="cell_iname",
            data=cp_subset,
            order=allowed_doses);
plt.title(cp);
plt.legend(bbox_to_anchor=(1.2,1), loc="upper right");
plt.ylim(0,1);

# %%
cp = "bortezomib"
cp_subset = siginfo[siginfo["cmap_name"] == cp].dropna(subset=["tas"])

f, ax = plt.subplots(figsize=(10,7))
sns.pointplot(x="pert_idose",
            y="tas",
            hue="cell_iname",
            data=cp_subset,
            order=allowed_doses);
plt.title(cp);
plt.legend(bbox_to_anchor=(1.2,1), loc="upper right");
plt.ylim(0,1);

# %%
cp = "ibudilast"
cp_subset = siginfo[siginfo["cmap_name"] == cp].dropna(subset=["tas"])

f, ax = plt.subplots(figsize=(10,7))
sns.pointplot(x="pert_idose",
            y="tas",
            hue="cell_iname",
            data=cp_subset,
            order=allowed_doses);
plt.title(cp);
plt.legend(bbox_to_anchor=(1.2,1), loc="upper right");
plt.ylim(0,1);

# %% [markdown]
# # Quantifying dose response

# %% [markdown]
# The above examples were hand-picked, but what if we wanted to systematically categorize compound-cell pairs? How about slope of TAS against dose?

# %% [markdown]
# Let's get unique compound-cell line pairs

# %%
cp_cell_pairs = list({tuple(row) for row in siginfo[["cmap_name", "cell_iname"]].values})

# %% [markdown]
# Now let's compute a linear regression (TAS against log3 dose) for each compound-cell line pair.

# %% [markdown]
# The linear regression for each compound-cell pair takes about 5 minutes and the code is below. But for time's sake let's just read in the results.

# %%
cp_cell_metrics = pd.DataFrame(columns=["cmap_name",
                                        "cell_iname",
                                        "min_tas",
                                        "q25_tas",
                                        "median_tas",
                                        "q75_tas",
                                        "max_tas",
                                        "is_monotonic",
                                        "sd_tas",
                                        "n_doses",
                                        "lm_slope",
                                        "lm_intercept",
                                        "lm_rvalue",
                                        "lm_pvalue",
                                        "lm_stderr"])

i = 0
for cp_cell_pair in sorted(cp_cell_pairs):
    cp, cell = cp_cell_pair
    cp_cell_subset = siginfo[(siginfo["cmap_name"] == cp) &
                             (siginfo["cell_iname"] == cell)]
    # let's drop sigs with missing TAS (singlicates), and sort.
    cp_cell_subset = cp_cell_subset.dropna(subset=["tas"]).sort_values(["pert_dose"])
    
    # skip if we don't have enough points to calculate slope
    if len(cp_cell_subset["tas"]) < 2:
        continue

    tas_per_dose = cp_cell_subset["tas"]
    doses = cp_cell_subset["pert_dose"].values
    # log3 because doses are 3-fold dilution
    log3_doses = np.log(doses) / np.log(3)
    
    min_tas = tas_per_dose.min()
    q25_tas = tas_per_dose.quantile(0.25)
    median_tas = tas_per_dose.median()
    q75_tas = tas_per_dose.quantile(0.75)
    max_tas = tas_per_dose.max()
    is_monotonic = tas_per_dose.is_monotonic
    sd_tas = tas_per_dose.std()
    n_doses = len(doses)
    
    linregress_results = stats.linregress(log3_doses, tas_per_dose)
    slope = linregress_results.slope
    intercept = linregress_results.intercept
    rvalue = linregress_results.rvalue
    pvalue = linregress_results.pvalue
    stderr = linregress_results.stderr
    
    row = [cp, cell, min_tas, q25_tas, median_tas, q75_tas, max_tas, is_monotonic, sd_tas, n_doses,
           slope, intercept, rvalue, pvalue, stderr]
    cp_cell_metrics.loc[i] = row
    i += 1

# %%
# take a look at the first few rows
cp_cell_metrics.head()
# Out:
#   cmap_name cell_iname   min_tas   q25_tas  median_tas   q75_tas   max_tas  \
# 0   10-DEBC       A375  0.250336  0.265752    0.316824  0.352728  0.431502
# 1   10-DEBC       HA1E  0.080418  0.089374    0.109198  0.126371  0.346345
# 2   10-DEBC       HELA  0.075567  0.094545    0.104848  0.141841  0.195790
# 3   10-DEBC       HT29  0.090235  0.109422    0.150441  0.203087  0.291498
# 4   10-DEBC       MCF7  0.109670  0.139026    0.141311  0.170481  0.260272
#
#   is_monotonic    sd_tas n_doses  lm_slope  lm_intercept  lm_rvalue  \
# 0        False  0.068878       6  0.031353      0.334155   0.851583
# 1        False  0.101317       6  0.037465      0.158476   0.691802
# 2        False  0.044830       6  0.004421      0.122842   0.184478
# 3        False  0.076508       6  0.025020      0.176610   0.611798
# 4        False  0.053134       6 -0.000593      0.161599  -0.020897
#
#    lm_pvalue  lm_stderr
# 0   0.031407   0.009650
# 1   0.127842   0.019553
# 2   0.726423   0.011776
# 3   0.196800   0.016174
# 4   0.968660   0.014197

# %%
cp_cell_metrics["range_tas"] = cp_cell_metrics["max_tas"] - cp_cell_metrics["min_tas"]
cp_cell_metrics["lm_rsquared"] = cp_cell_metrics["lm_rvalue"]**2

# %% [markdown]
# Here we'll just read the precomputed results.

# %%
# download the pre-computed linear regression results
# !wget --quiet -O - https://s3.amazonaws.com/repo-assets.clue.io/cp_cell_linregress_metrics.txt.gz | gunzip > cp_cell_linregress_metrics.txt

# %%
cp_cell_metrics = pd.read_csv('cp_cell_linregress_metrics.txt', sep='\t', na_values='-666')

# %%
cp_cell_metrics.head()
# Out:
#      cmap_name          brew_prefix cell_iname   min_tas   q25_tas  \
# 0     MLN-2238  REP.A024_JURKAT_24H     JURKAT  0.067137  0.148203
# 1   tioguanine    REP.A025_A375_24H       A375  0.110061  0.285966
# 2    alvocidib    REP.A026_HT29_24H       HT29  0.146678  0.212222
# 3  midostaurin    REP.A010_MCF7_24H       MCF7  0.008215  0.122264
# 4  meisoindigo     REP.A010_PC3_24H        PC3  0.147486  0.158343
#
#    median_tas   q75_tas   max_tas  is_monotonic    sd_tas  n_doses  lm_slope  \
# 0    0.387222  0.794329  0.833469          True  0.356069        5  0.216811
# 1    0.640109  0.763379  0.791588          True  0.304231        5  0.184405
# 2    0.584040  0.759094  0.792575          True  0.303084        5  0.183003
# 3    0.301485  0.795651  0.797814         False  0.372493        5  0.177832
# 4    0.235921  0.791956  0.792333         False  0.336698        5  0.174497
#
#    lm_intercept  lm_rvalue  lm_pvalue  lm_stderr  range_tas  lm_rsquared  \
# 0      0.642839   0.966413   0.007352   0.033288   0.766332     0.933954
# 1      0.500219   0.956219   0.010924   0.032584   0.681527     0.914354
# 2      0.665006   0.958320   0.010151   0.031499   0.645897     0.918377
# 3      0.424614   0.922777   0.025460   0.042874   0.789599     0.851517
# 4      0.583573   0.822553   0.087302   0.069653   0.644847     0.676594
#
#                  category
# 0  dose-responsive-strong
# 1  dose-responsive-strong
# 2  dose-responsive-strong
# 3  dose-responsive-strong
# 4                   other

# %% [markdown]
# How many compound-cell line pairs?

# %%
n_cp_cell_pairs = len(cp_cell_metrics)
n_cp_cell_pairs
# Out:
# 12936

# %% [markdown]
# How many pairs are we left with if we want only those pairs where we have data in at least 5 doses? We want to make sure our slope metric is robust.

# %%
(cp_cell_metrics["n_doses"] >= 5).sum()
# Out:
# 12936

# %% [markdown]
# That's not bad-- let's subset to just those.

# %%
cp_cell_metrics = cp_cell_metrics[cp_cell_metrics["n_doses"] >= 5]

# %% [markdown]
# ## Let's take a look at the compound-cell pair with the highest slope.

# %%
cp_cell_metrics.sort_values(["lm_slope"], ascending=False).head(5)
# Out:
#      cmap_name          brew_prefix cell_iname   min_tas   q25_tas  \
# 0     MLN-2238  REP.A024_JURKAT_24H     JURKAT  0.067137  0.148203
# 1   tioguanine    REP.A025_A375_24H       A375  0.110061  0.285966
# 2    alvocidib    REP.A026_HT29_24H       HT29  0.146678  0.212222
# 3  midostaurin    REP.A010_MCF7_24H       MCF7  0.008215  0.122264
# 4  meisoindigo     REP.A010_PC3_24H        PC3  0.147486  0.158343
#
#    median_tas   q75_tas   max_tas  is_monotonic    sd_tas  n_doses  lm_slope  \
# 0    0.387222  0.794329  0.833469          True  0.356069        5  0.216811
# 1    0.640109  0.763379  0.791588          True  0.304231        5  0.184405
# 2    0.584040  0.759094  0.792575          True  0.303084        5  0.183003
# 3    0.301485  0.795651  0.797814         False  0.372493        5  0.177832
# 4    0.235921  0.791956  0.792333         False  0.336698        5  0.174497
#
#    lm_intercept  lm_rvalue  lm_pvalue  lm_stderr  range_tas  lm_rsquared  \
# 0      0.642839   0.966413   0.007352   0.033288   0.766332     0.933954
# 1      0.500219   0.956219   0.010924   0.032584   0.681527     0.914354
# 2      0.665006   0.958320   0.010151   0.031499   0.645897     0.918377
# 3      0.424614   0.922777   0.025460   0.042874   0.789599     0.851517
# 4      0.583573   0.822553   0.087302   0.069653   0.644847     0.676594
#
#                  category
# 0  dose-responsive-strong
# 1  dose-responsive-strong
# 2  dose-responsive-strong
# 3  dose-responsive-strong
# 4                   other

# %% [markdown]
# Does it look dose-responsive?

# %%
cp = "ixazomib" # aka MLN-2238
cell = "JURKAT"
cp_cell_subset = siginfo[(siginfo["cmap_name"] == cp) &
                         (siginfo["cell_iname"] == cell)].dropna(subset=["tas"])

# f, ax = plt.subplots(figsize=(10,7))
sns.pointplot(x="pert_idose",
            y="tas",
            data=cp_cell_subset,
            order=allowed_doses);
plt.title("{}; {}".format(cp,cell));
plt.ylim(0,1);

# %% [markdown]
# ## What's the distribution of slopes?

# %%
sns.distplot(cp_cell_metrics["lm_slope"], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Considering goodness of fit for dose-responsiveness

# %% [markdown]
# To be more conservative in our dose-responsive labeling, we might exclude situations where the slope is high, *but* $r^{2}$ < 0.7.
#
# Let's take a look at an example:

# %%
cp_cell_metrics[(cp_cell_metrics["lm_slope"] > 0.15) &
                (cp_cell_metrics["lm_rsquared"] < 0.7)]
# Out:
#      cmap_name       brew_prefix cell_iname   min_tas   q25_tas  median_tas  \
# 4  meisoindigo  REP.A010_PC3_24H        PC3  0.147486  0.158343    0.235921
#
#     q75_tas   max_tas  is_monotonic    sd_tas  n_doses  lm_slope  \
# 4  0.791956  0.792333         False  0.336698        5  0.174497
#
#    lm_intercept  lm_rvalue  lm_pvalue  lm_stderr  range_tas  lm_rsquared  \
# 4      0.583573   0.822553   0.087302   0.069653   0.644847     0.676594
#
#   category
# 4    other

# %%
siginfo[siginfo.cmap_name=='meisoindigo']
# Out:
#                            sig_id        pert_id    cmap_name  pert_dose  \
# 1428    REP.A010_MDAMB231_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 1541        REP.A010_HELA_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 2406      REP.A010_JURKAT_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 5160      REP.A010_MCF10A_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 9785        REP.A010_HT29_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 9862        REP.A010_THP1_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 11090     REP.A010_HEK293_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 13745       REP.A010_A549_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 14243       REP.A010_MCF7_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 14413       REP.A010_HA1E_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 16092        REP.A010_PC3_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 17133       REP.A010_A375_24H:K01  BRD-K14529030  meisoindigo  10.000000
# 20861       REP.A010_THP1_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 21327   REP.A010_MDAMB231_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 21643     REP.A010_JURKAT_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 22013       REP.A010_HELA_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 22181        REP.A010_PC3_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 22805       REP.A010_A549_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 23862       REP.A010_A375_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 25242     REP.A010_MCF10A_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 27139       REP.A010_HA1E_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 30896       REP.A010_HT29_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 31145     REP.A010_HEK293_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 32496       REP.A010_MCF7_24H:K03  BRD-K14529030  meisoindigo   1.111110
# 38559       REP.A010_HELA_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 40468     REP.A010_MCF10A_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 40675       REP.A010_MCF7_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 42005       REP.A010_HA1E_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 42394        REP.A010_PC3_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 43760       REP.A010_HT29_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 43884   REP.A010_MDAMB231_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 45682     REP.A010_JURKAT_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 46749       REP.A010_A375_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 46909       REP.A010_THP1_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 48560       REP.A010_YAPC_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 49175       REP.A010_A549_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 53085     REP.A010_HEK293_24H:K04  BRD-K14529030  meisoindigo   0.370370
# 58606       REP.A010_YAPC_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 60197     REP.A010_JURKAT_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 61365       REP.A010_A375_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 61545       REP.A010_MCF7_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 62571       REP.A010_HT29_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 62778     REP.A010_HEK293_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 64827       REP.A010_A549_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 65439       REP.A010_HELA_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 65660        REP.A010_PC3_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 68551       REP.A010_HA1E_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 68915   REP.A010_MDAMB231_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 69511     REP.A010_MCF10A_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 70583       REP.A010_THP1_24H:K05  BRD-K14529030  meisoindigo   0.123457
# 73716       REP.A010_YAPC_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 74597       REP.A010_HT29_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 74934        REP.A010_PC3_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 75386       REP.A010_MCF7_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 78308       REP.A010_HELA_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 80837       REP.A010_THP1_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 81944       REP.A010_A375_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 84608     REP.A010_HEK293_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 84868     REP.A010_JURKAT_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 85049       REP.A010_A549_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 86380       REP.A010_HA1E_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 87210     REP.A010_MCF10A_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 87882   REP.A010_MDAMB231_24H:K02  BRD-K14529030  meisoindigo   3.333330
# 90585       REP.A010_HA1E_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 90734       REP.A010_YAPC_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 93106     REP.A010_JURKAT_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 94789     REP.A010_HEK293_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 97213     REP.A010_MCF10A_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 99144       REP.A010_MCF7_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 99146       REP.A010_THP1_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 101176       REP.A010_PC3_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 101197      REP.A010_A549_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 101798      REP.A010_HELA_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 102700      REP.A010_HT29_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 105499  REP.A010_MDAMB231_24H:K06  BRD-K14529030  meisoindigo   0.041152
# 106660      REP.A010_A375_24H:K06  BRD-K14529030  meisoindigo   0.041152
#
#        pert_idose pert_itime cell_iname  nsample       tas
# 1428        10 uM       24 h   MDAMB231        3  0.257596
# 1541        10 uM       24 h       HELA        3  0.800163
# 2406        10 uM       24 h     JURKAT        3  0.005538
# 5160        10 uM       24 h     MCF10A        2  0.009101
# 9785        10 uM       24 h       HT29        3  0.708413
# 9862        10 uM       24 h       THP1        3  0.053035
# 11090       10 uM       24 h     HEK293        3  0.110770
# 13745       10 uM       24 h       A549        3  0.184287
# 14243       10 uM       24 h       MCF7        3  0.800461
# 14413       10 uM       24 h       HA1E        3  0.728794
# 16092       10 uM       24 h        PC3        2  0.669944
# 17133       10 uM       24 h       A375        3  0.791574
# 20861     1.11 uM       24 h       THP1        3  0.023334
# 21327     1.11 uM       24 h   MDAMB231        3  0.238918
# 21643     1.11 uM       24 h     JURKAT        3  0.003354
# 22013     1.11 uM       24 h       HELA        2  0.774295
# 22181     1.11 uM       24 h        PC3        3  0.792333
# 22805     1.11 uM       24 h       A549        3  0.140334
# 23862     1.11 uM       24 h       A375        3  0.811240
# 25242     1.11 uM       24 h     MCF10A        2  0.008338
# 27139     1.11 uM       24 h       HA1E        3  0.796885
# 30896     1.11 uM       24 h       HT29        3  0.679590
# 31145     1.11 uM       24 h     HEK293        3  0.186409
# 32496     1.11 uM       24 h       MCF7        3  0.802914
# 38559     0.37 uM       24 h       HELA        3  0.119570
# 40468     0.37 uM       24 h     MCF10A        2  0.017017
# 40675     0.37 uM       24 h       MCF7        3  0.151973
# 42005     0.37 uM       24 h       HA1E        3  0.158853
# 42394     0.37 uM       24 h        PC3        3  0.158343
# 43760     0.37 uM       24 h       HT29        3  0.143639
# 43884     0.37 uM       24 h   MDAMB231        3  0.234053
# 45682     0.37 uM       24 h     JURKAT        3  0.003784
# 46749     0.37 uM       24 h       A375        3  0.244418
# 46909     0.37 uM       24 h       THP1        3  0.046996
# 48560     0.37 uM       24 h       YAPC        2  0.195884
# 49175     0.37 uM       24 h       A549        3  0.170017
# 53085     0.37 uM       24 h     HEK293        3  0.157628
# 58606    0.125 uM       24 h       YAPC        2  0.198223
# 60197    0.125 uM       24 h     JURKAT        3  0.003646
# 61365    0.125 uM       24 h       A375        3  0.182649
# 61545    0.125 uM       24 h       MCF7        3  0.183448
# 62571    0.125 uM       24 h       HT29        3  0.140031
# 62778    0.125 uM       24 h     HEK293        3  0.103362
# 64827    0.125 uM       24 h       A549        3  0.222742
# 65439    0.125 uM       24 h       HELA        3  0.141833
# 65660    0.125 uM       24 h        PC3        3  0.147486
# 68551    0.125 uM       24 h       HA1E        3  0.141271
# 68915    0.125 uM       24 h   MDAMB231        3  0.243833
# 69511    0.125 uM       24 h     MCF10A        2  0.006631
# 70583    0.125 uM       24 h       THP1        3  0.069342
# 73716     3.33 uM       24 h       YAPC        2  0.759092
# 74597     3.33 uM       24 h       HT29        3  0.684765
# 74934     3.33 uM       24 h        PC3        3  0.791956
# 75386     3.33 uM       24 h       MCF7        3  0.805166
# 78308     3.33 uM       24 h       HELA        2  0.740632
# 80837     3.33 uM       24 h       THP1        3  0.058551
# 81944     3.33 uM       24 h       A375        3  0.820545
# 84608     3.33 uM       24 h     HEK293        3  0.170668
# 84868     3.33 uM       24 h     JURKAT        3  0.002860
# 85049     3.33 uM       24 h       A549        3  0.169612
# 86380     3.33 uM       24 h       HA1E        3  0.755198
# 87210     3.33 uM       24 h     MCF10A        2  0.011305
# 87882     3.33 uM       24 h   MDAMB231        3  0.265846
# 90585     0.04 uM       24 h       HA1E        3  0.064258
# 90734     0.04 uM       24 h       YAPC        2  0.205817
# 93106     0.04 uM       24 h     JURKAT        3  0.003503
# 94789     0.04 uM       24 h     HEK293        3  0.139088
# 97213     0.04 uM       24 h     MCF10A        2  0.167524
# 99144     0.04 uM       24 h       MCF7        3  0.270309
# 99146     0.04 uM       24 h       THP1        3  0.104135
# 101176    0.04 uM       24 h        PC3        3  0.235921
# 101197    0.04 uM       24 h       A549        3  0.186398
# 101798    0.04 uM       24 h       HELA        3  0.114676
# 102700    0.04 uM       24 h       HT29        3  0.072646
# 105499    0.04 uM       24 h   MDAMB231        3  0.181903
# 106660    0.04 uM       24 h       A375        3  0.195093

# %%
cp = "meisoindigo"
cell = "PC3"
cp_cell_subset = siginfo[(siginfo["cmap_name"] == cp) &
                         (siginfo["cell_iname"] == cell)].dropna(subset=["tas"])

# f, ax = plt.subplots(figsize=(10,7))
sns.pointplot(x="pert_idose",
            y="tas",
            data=cp_cell_subset,
            order=allowed_doses);
plt.title("{}; {}".format(cp,cell));
plt.ylim(0,1);

# %% [markdown]
# We'll want to categorize this high slope, poor fit case as "other"

# %% [markdown]
# Let's look at the r-squared distribution

# %%
sns.distplot(cp_cell_metrics["lm_rsquared"], kde=False)
plt.axvline(0.7, color="red", linestyle="dashed");
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# This is a fairly strict fit requirement for dose-responsiveness, but for this first pass heuristic, we're just interested in being able to systematically reveal some interesting examples.

# %% [markdown]
# ## Picking a dose-responsive slope threshold

# %% [markdown]
# Let's plot TAS against dose for slope bins of 0.01 from, say 0 to 0.1.
#
# This will help us tune our heuristic for calling a compound in a cell dose-repsonsive.

# %%
slope_bins = [(i/100.0, (i+1)/100.0) for i in range(0,10)]
slope_bins
# Out:
# [(0.0, 0.01),
#  (0.01, 0.02),
#  (0.02, 0.03),
#  (0.03, 0.04),
#  (0.04, 0.05),
#  (0.05, 0.06),
#  (0.06, 0.07),
#  (0.07, 0.08),
#  (0.08, 0.09),
#  (0.09, 0.1)]

# %% [markdown]
# Let's randomly sample 50 compound-cell pairs with a good linear fit ($r^{2}$ > 0.7) for each slope bin and take a look

# %%
# set random seed so results are reproducible
np.random.seed(42)

f, ax = plt.subplots(2, 5, figsize=(15,8), sharey=True, sharex=True)
ax_list = ax.reshape(-1)
for i, slope_bin in enumerate(slope_bins):
    cp_cell_subset = cp_cell_metrics[(cp_cell_metrics["lm_slope"].between(*slope_bin)) &
                                     (cp_cell_metrics["lm_rsquared"] > 0.7)]
    # let's sample 50 cp-cell pairs, unless there are fewer
    if len(cp_cell_subset) >= 50:
        sample = cp_cell_subset.sample(50)
    else:
        sample = cp_cell_subset
    cp_cell_pairs = zip(sample["cmap_name"].values, sample["cell_iname"].values)
    siginfo_sample = pd.DataFrame()

    for pair in cp_cell_pairs:
        cp, cell = pair
        # subset signatures with current compound-cell combination
        siginfo_subset = siginfo[(siginfo["cmap_name"] == cp) &
                                 (siginfo["cell_iname"] == cell)]
        cur_ax = ax_list[i]
        sns.pointplot(x="pert_idose",
                      y="tas",
                      data=siginfo_subset,
                      order=allowed_doses,
                      ax=cur_ax);
        cur_ax.set_title("({:.2f}, {:.2f})".format(*slope_bin));
        cur_ax.set_ylim(0,1);
        cur_ax.set_xticklabels(allowed_doses, rotation=30);
    plt.tight_layout();

# %% [markdown]
# Let's define dose-responsive compound-cell pairs as those with a slope > 0.02

# %% [markdown]
# ## Considering TAS range for low slope (defining inert/saturated)

# %% [markdown]
# For those with low slopes, let's waive the good fit requirement, and require a TAS range < 0.2.

# %%
cp_cell_metrics[(cp_cell_metrics["lm_slope"] < 0.02) &
                (cp_cell_metrics["range_tas"] > 0.2)].head()
# Out:
#         cmap_name        brew_prefix cell_iname   min_tas   q25_tas  \
# 3973      abt-239  REP.A004_MCF7_24H       MCF7  0.040290  0.084394
# 3975    semaxanib  REP.A018_HELA_24H       HELA  0.145468  0.157457
# 3987  epinephrine  REP.A018_HELA_24H       HELA  0.081459  0.082977
# 3992   cp-945,598  REP.A005_A375_24H       A375  0.071388  0.105589
# 3995   etravirine  REP.A025_HA1E_24H       HA1E  0.113958  0.150974
#
#       median_tas   q75_tas   max_tas  is_monotonic    sd_tas  n_doses  \
# 3973    0.097241  0.115669  0.242574         False  0.068768        6
# 3975    0.168816  0.207248  0.373093         False  0.086252        6
# 3987    0.100777  0.158408  0.304930         False  0.087854        6
# 3992    0.128589  0.180965  0.321682         False  0.090698        6
# 3995    0.191048  0.229101  0.332573         False  0.078849        6
#
#       lm_slope  lm_intercept  lm_rvalue  lm_pvalue  lm_stderr  range_tas  \
# 3973  0.019998      0.121350   0.545488   0.262925   0.015363   0.202284
# 3975  0.019993      0.213124   0.434815   0.388882   0.020704   0.227625
# 3987  0.019921      0.148542   0.425347   0.400456   0.021194   0.223471
# 3992  0.019905      0.165866   0.411665   0.417384   0.022032   0.250294
# 3995  0.019881      0.209429   0.472961   0.343457   0.018518   0.218615
#
#       lm_rsquared category
# 3973     0.297558    other
# 3975     0.189064    other
# 3987     0.180920    other
# 3992     0.169468    other
# 3995     0.223692    other

# %% [markdown]
# Let's take a look at one of these low-slope, high TAS range cases:

# %%
cp = "semaxanib"
cell = "HELA"
cp_cell_subset = siginfo[(siginfo["cmap_name"] == cp) &
                         (siginfo["cell_iname"] == cell)].dropna(subset=["tas"])

# f, ax = plt.subplots(figsize=(10,7))
sns.pointplot(x="pert_idose",
            y="tas",
            data=cp_cell_subset,
            order=allowed_doses);
plt.title("{}; {}".format(cp,cell));
plt.ylim(0,1);

# %% [markdown]
# We'll want to categorize this low-slope, high TAS range case as "other"

# %% [markdown]
# ### For our dose-response categories, we'll exclude cases where the fit is poor *except* where we suspect the dose curve is flat (low slope with low TAS range)

# %% [markdown]
# ## Define heuristics for categorizing

# %% [markdown]
# Let's define the following categories:
#
# **dose-responsive (strong)**:
# * high slope with good fit
# * median TAS >= 0.2
#
# **dose-responsive (subtle)**:
# * high slope with good fit
# * median TAS < 0.2
#
# **saturated**:
# * low slope with low TAS range
# * median TAS >= 0.2
#
# **inert**:
# * low slope with low TAS range
# * median TAS < 0.2
#
# **other**:
# * everything else

# %% [markdown]
# Now let's categorize according to these heuristics

# %%
cp_cell_metrics["category"] = "other"

cp_cell_metrics.loc[((cp_cell_metrics["lm_slope"] > 0.02) &
                     (cp_cell_metrics["lm_rsquared"] > 0.7) &
                     (cp_cell_metrics["median_tas"] >= 0.2)), "category"] = "dose-responsive-strong"

cp_cell_metrics.loc[((cp_cell_metrics["lm_slope"] > 0.02) &
                     (cp_cell_metrics["lm_rsquared"] > 0.7) &
                     (cp_cell_metrics["median_tas"] < 0.2)), "category"] = "dose-responsive-subtle"

cp_cell_metrics.loc[((cp_cell_metrics["lm_slope"] <= 0.02) &
                     (cp_cell_metrics["range_tas"] < 0.2) &
                     (cp_cell_metrics["median_tas"] >= 0.2)), "category"] = "saturated"

cp_cell_metrics.loc[((cp_cell_metrics["lm_slope"] <= 0.02) &
                     (cp_cell_metrics["range_tas"] < 0.2) &
                     (cp_cell_metrics["median_tas"] < 0.2)), "category"] = "inert"

# %% [markdown]
# And let's take a look at the dose-response categories ("other" excluded)

# %%
# f, ax = plt.subplots()
sns.scatterplot(x="lm_slope",
                y="median_tas",
                data=cp_cell_metrics[cp_cell_metrics["category"] != "other"],
                alpha=0.05, edgecolor=None);
plt.axhline(0.2, color="red", linestyle="dotted");
plt.axvline(0.02, color="red", linestyle="dotted");
plt.ylim(0,1.0);

plt.text(0.22, 0.9, "dose-responsive-strong", horizontalalignment="right", weight="semibold");
plt.text(0.22, 0.08, "dose-responsive-subtle", horizontalalignment="right", weight="semibold");
plt.text(-0.05, 0.08, "inert", horizontalalignment="left", weight="semibold");
plt.text(-0.05, 0.9, "saturated", horizontalalignment="left", weight="semibold");

# %%
cats = ["dose-responsive-strong", "dose-responsive-subtle", "saturated", "inert", "other"]
arr = [(cp_cell_metrics["category"] == x).sum() / n_cp_cell_pairs * 100 for x in cats]

# %%
sns.barplot(x=cats, y=pd.Series(arr))
plt.xticks(rotation=30)

print("{:.2f}% dose-responsive-strong".format((cp_cell_metrics["category"] == "dose-responsive-strong").sum() / n_cp_cell_pairs * 100))
print("{:.2f}% dose-responsive=subtle".format((cp_cell_metrics["category"] == "dose-responsive-subtle").sum() / n_cp_cell_pairs * 100))
print("{:.2f}% saturated".format((cp_cell_metrics["category"] == "saturated").sum() / n_cp_cell_pairs * 100))
print("{:.2f}% inert".format((cp_cell_metrics["category"] == "inert").sum() / n_cp_cell_pairs * 100))
print("{:.2f}% other".format((cp_cell_metrics["category"] == "other").sum() / n_cp_cell_pairs * 100))
# Out:
# 7.24% dose-responsive-strong
# 5.38% dose-responsive=subtle
# 3.95% saturated
# 57.59% inert
# 25.84% other

# %% [markdown]
# # Finding cell-specific dose-response

# %% [markdown]
# Let's take a look at how many cases in each category appear per compound

# %%
# get categories represented per compound
agg_categorized = cp_cell_metrics.groupby(["cmap_name"])["category"].apply(list).reset_index()
agg_categorized["n_cells_dose-responsive-strong"] = agg_categorized["category"].apply(lambda x: x.count("dose-responsive-strong"))
agg_categorized["n_cells_dose-responsive-subtle"] = agg_categorized["category"].apply(lambda x: x.count("dose-responsive-subtle"))
agg_categorized["n_cells_saturated"] = agg_categorized["category"].apply(lambda x: x.count("saturated"))
agg_categorized["n_cells_inert"] = agg_categorized["category"].apply(lambda x: x.count("inert"))
agg_categorized["n_cells_other"] = agg_categorized["category"].apply(lambda x: x.count("other"))
agg_categorized["n_cells"] = agg_categorized["category"].apply(lambda x: len(x))
agg_categorized = agg_categorized.drop(["category"], axis=1)
agg_categorized.head()
# Out:
#                          cmap_name  n_cells_dose-responsive-strong  \
# 0                          10-DEBC                               1
# 1  17-hydroxyprogesterone-caproate                               0
# 2           2',5'-dideoxyadenosine                               0
# 3                    2-iminobiotin                               0
# 4               2-methoxyestradiol                               3
#
#    n_cells_dose-responsive-subtle  n_cells_saturated  n_cells_inert  \
# 0                               0                  0              3
# 1                               1                  0              2
# 2                               0                  0              4
# 3                               0                  0              5
# 4                               1                  0              1
#
#    n_cells_other  n_cells
# 0              2        6
# 1              5        8
# 2              1        5
# 3              3        8
# 4              1        6

# %% [markdown]
# We can now look for various combinations of our categories to find interesting differential cell line activity

# %% [markdown]
# Let's start with a case where the compound was:
# * inert in a majority of cell lines
# * saturated or dose-responsive-strong in at least 1 cell line

# %%
agg_categorized[(agg_categorized["n_cells_inert"] / agg_categorized["n_cells"] > 1/2) &
                ((agg_categorized["n_cells_saturated"] >= 1) |
                (agg_categorized["n_cells_dose-responsive-strong"] >= 1))]
# Out:
#                         cmap_name  n_cells_dose-responsive-strong  \
# 61                    PF-04217903                               0
# 71                       SR-27897                               0
# 74                        TAK-715                               0
# 77                          TTNPB                               0
# 86                       ZK-93423                               2
# 97                  acetazolamide                               0
# 120                   alaproclate                               0
# 125                    alizapride                               0
# 138                   ambrisentan                               0
# 161                    amlodipine                               0
# 166                       ampalex                               0
# 172                    anagrelide                               0
# 187                      apixaban                               0
# 188                      apocynin                               0
# 189                    apremilast                               0
# 192                    argatroban                               0
# 213                    atracurium                               0
# 243                     balicatib                               0
# 246                    barasertib                               1
# 275                   bezafibrate                               0
# 282                    birinapant                               1
# 285                    bitopertin                               0
# 298                     brivudine                               0
# 305                      budipine                               0
# 312                      busulfan                               0
# 318                   cabergoline                               0
# 343               castanospermine                               0
# 361               chloramphenicol                               0
# 377                    cilomilast                               1
# 409                     clozapine                               0
# 417                    conivaptan                               0
# 424                       ct-7758                               0
# 425                      cts-1027                               0
# 432                     cyclizine                               0
# 437                    cytarabine                               0
# 447                   danegaptide                               0
# 500                     dinoprost                               0
# 506                  disopyramide                               0
# 507                    disulfiram                               0
# 540                     edoxudine                               1
# 551                    emedastine                               0
# 567                  epitiostanol                               0
# 605                   famciclovir                               0
# 625                   finasteride                               0
# 634               fludroxycortide                               2
# 643                     flutamide                               0
# 645                  flutrimazole                               0
# 649                     fomocaine                               2
# 655                    fosinopril                               0
# 659                   fulvestrant                               0
# 673                      gdc-0834                               0
# 677                   gemfibrozil                               0
# 690                    gliquidone                               0
# 707                   halcinonide                               0
# 717                hydrocortisone                               0
# 738                    iguratimod                               0
# 750                     indirubin                               0
# 788                     ketorolac                               0
# 794                  l-citrulline                               0
# 801                    lafutidine                               0
# 842                   linsidomine                               0
# 849                    lodoxamide                               0
# 881                     ly2886721                               0
# 885                   maprotiline                               0
# 900   medroxyprogesterone-acetate                               0
# 902                    mefloquine                               0
# 903                   meglitinide                               0
# 915                    mepyramine                               0
# 927                     metformin                               0
# 990                    naftopidil                               0
# 1003                  nemonapride                               0
# 1013                  nicergoline                               0
# 1025                   nizofenone                               1
# 1028               norethisterone                               1
# 1030                   norgestrel                               2
# 1035                     nutlin-3                               0
# 1054                     orlistat                               2
# 1055                   ornidazole                               0
# 1104                  pf-03084014                               0
# 1121               phenylbutazone                               0
# 1127                  piclamilast                               0
# 1142                 pioglitazone                               4
# 1144                    piracetam                               0
# 1173                   proglumide                               0
# 1191                    quinapril                               0
# 1218                   resatorvid                               0
# 1224                  retapamulin                               0
# 1229                    ribavirin                               0
# 1253                   roquinimex                               0
# 1255                rosiglitazone                               0
# 1258                    rottlerin                               1
# 1280                    sb-271046                               0
# 1281                    sb-683698                               0
# 1297                   sep-227900                               0
# 1316                    sofalcone                               0
# 1335                  sulfadoxine                               0
# 1353                      tak-285                               0
# 1356                    taladegib                               0
# 1363                    tamoxifen                               1
# 1367                   taranabant                               0
# 1382                  telmesteine                               1
# 1395                 testosterone                               1
# 1396                tetrabenazine                               0
# 1405                 theophylline                               0
# 1415                     tibolone                               0
# 1420                  timofibrate                               0
# 1426                    tipiracil                               0
# 1444                   tonabersat                               0
# 1445                   topiramate                               0
# 1455                     tramadol                               0
# 1463      triamcinolone-acetonide                               0
# 1479                 troglitazone                               2
# 1490                     ursodiol                               0
# 1523                       vx-661                               0
# 1546                     zolpidem                               0
#
#       n_cells_dose-responsive-subtle  n_cells_saturated  n_cells_inert  \
# 61                                 0                  1              7
# 71                                 0                  1              6
# 74                                 0                  1              7
# 77                                 0                  4              6
# 86                                 1                  0              5
# 97                                 0                  2              8
# 120                                1                  1              7
# 125                                0                  1              7
# 138                                0                  1              6
# 161                                1                  1              7
# 166                                0                  1              7
# 172                                0                  2              6
# 187                                0                  1              5
# 188                                0                  1              7
# 189                                0                  1              3
# 192                                0                  1              7
# 213                                0                  1              6
# 243                                0                  1              5
# 246                                0                  0              3
# 275                                0                  1              9
# 282                                0                  1              5
# 285                                0                  1              8
# 298                                0                  1              7
# 305                                0                  1              5
# 312                                0                  1              4
# 318                                0                  1              8
# 343                                0                  1              5
# 361                                0                  1              5
# 377                                1                  1              6
# 409                                0                  1              6
# 417                                0                  1              7
# 424                                0                  1              5
# 425                                0                  1              7
# 432                                0                  1              9
# 437                                0                  1              9
# 447                                0                  1              6
# 500                                0                  1              7
# 506                                0                  1              6
# 507                                0                  1              5
# 540                                1                  0              6
# 551                                0                  1              6
# 567                                0                  2              7
# 605                                0                  3              6
# 625                                0                  2              6
# 634                                0                  1              7
# 643                                0                  1              7
# 645                                0                  1              6
# 649                                1                  0              7
# 655                                0                  1              5
# 659                                0                  1              7
# 673                                0                  1              7
# 677                                0                  1              6
# 690                                1                  1              7
# 707                                0                  1              3
# 717                                0                  3              5
# 738                                0                  1              8
# 750                                0                  2              6
# 788                                1                  1              8
# 794                                0                  1              8
# 801                                0                  1              7
# 842                                0                  2              6
# 849                                0                  1              8
# 881                                0                  1              7
# 885                                0                  1              7
# 900                                0                  2              7
# 902                                0                  1              3
# 903                                0                  1              6
# 915                                0                  2              3
# 927                                0                  2              5
# 990                                0                  1              5
# 1003                               0                  1              8
# 1013                               0                  1              9
# 1025                               0                  0              7
# 1028                               0                  0              6
# 1030                               0                  1              6
# 1035                               0                  1              7
# 1054                               0                  0              6
# 1055                               0                  1              4
# 1104                               1                  1              6
# 1121                               0                  1              6
# 1127                               0                  1              8
# 1142                               0                  0              7
# 1144                               0                  1              4
# 1173                               1                  2              6
# 1191                               0                  1              8
# 1218                               0                  1              8
# 1224                               1                  1              6
# 1229                               0                  1              5
# 1253                               0                  2              7
# 1255                               0                  1              4
# 1258                               0                  0              8
# 1280                               0                  1              8
# 1281                               0                  1              7
# 1297                               0                  2              7
# 1316                               1                  1              7
# 1335                               0                  2              3
# 1353                               0                  2              6
# 1356                               0                  1              8
# 1363                               0                  0              4
# 1367                               0                  1              6
# 1382                               0                  0              7
# 1395                               0                  0              6
# 1396                               0                  1              5
# 1405                               0                  1              7
# 1415                               0                  1              6
# 1420                               0                  1              7
# 1426                               0                  1              6
# 1444                               0                  1              4
# 1445                               0                  1              7
# 1455                               0                  1              4
# 1463                               0                  2              5
# 1479                               1                  1              6
# 1490                               0                  1              3
# 1523                               0                  1              3
# 1546                               0                  3              6
#
#       n_cells_other  n_cells
# 61                0        8
# 71                1        8
# 74                2       10
# 77                0       10
# 86                0        8
# 97                1       11
# 120               1       10
# 125               2       10
# 138               3       10
# 161               1       10
# 166               3       11
# 172               0        8
# 187               2        8
# 188               2       10
# 189               1        5
# 192               0        8
# 213               1        8
# 243               2        8
# 246               1        5
# 275               0       10
# 282               2        9
# 285               1       10
# 298               2       10
# 305               1        7
# 312               1        6
# 318               2       11
# 343               0        6
# 361               0        6
# 377               1       10
# 409               4       11
# 417               3       11
# 424               1        7
# 425               2       10
# 432               0       10
# 437               1       11
# 447               1        8
# 500               2       10
# 506               1        8
# 507               1        7
# 540               2       10
# 551               1        8
# 567               1       10
# 605               0        9
# 625               2       10
# 634               0       10
# 643               3       11
# 645               3       10
# 649               0       10
# 655               0        6
# 659               2       10
# 673               2       10
# 677               0        7
# 690               2       11
# 707               0        4
# 717               1        9
# 738               2       11
# 750               0        8
# 788               1       11
# 794               1       10
# 801               0        8
# 842               1        9
# 849               1       10
# 881               0        8
# 885               0        8
# 900               0        9
# 902               1        5
# 903               3       10
# 915               0        5
# 927               2        9
# 990               3        9
# 1003              2       11
# 1013              0       10
# 1025              2       10
# 1028              1        8
# 1030              2       11
# 1035              3       11
# 1054              0        8
# 1055              1        6
# 1104              2       10
# 1121              1        8
# 1127              1       10
# 1142              0       11
# 1144              1        6
# 1173              1       10
# 1191              0        9
# 1218              1       10
# 1224              0        8
# 1229              0        6
# 1253              0        9
# 1255              1        6
# 1258              1       10
# 1280              1       10
# 1281              1        9
# 1297              1       10
# 1316              0        9
# 1335              0        5
# 1353              3       11
# 1356              1       10
# 1363              1        6
# 1367              3       10
# 1382              0        8
# 1395              1        8
# 1396              0        6
# 1405              0        8
# 1415              1        8
# 1420              0        8
# 1426              4       11
# 1444              0        5
# 1445              0        8
# 1455              1        6
# 1463              1        8
# 1479              1       11
# 1490              0        4
# 1523              1        5
# 1546              1       10

# %% [markdown]
# ## A few examples of differential cell line dose-responsiveness

# %%
cp = "fulvestrant"
cp_subset = siginfo[siginfo["cmap_name"] == cp].dropna(subset=["tas"])

f, ax = plt.subplots()
sns.pointplot(x="pert_idose", y="tas", hue="cell_iname", data=cp_subset, order=allowed_doses);
plt.title(cp);
plt.legend(bbox_to_anchor=(1.35,1), loc="upper right");
plt.ylim(0,1);

# %% [markdown]
# Fulvestrant is an estrogen receptor antagonist, and the two breast cancer lines were the only ones not to be categorized as inert or other. MCF7 was called saturated, and MDAMB231 was called dose-responsive. Interestingly, MCF10A, a non-cancerous breast line was called inert.

# %%
# norethisterone
cp = "BRD-A39415247"
cp_subset = siginfo[siginfo["cmap_name"] == cp].dropna(subset=["tas"])

f, ax = plt.subplots()
sns.pointplot(x="pert_idose", y="tas", hue="cell_iname", data=cp_subset, order=allowed_doses);
plt.title(cp);
plt.legend(bbox_to_anchor=(1.35,1), loc="upper right");
plt.ylim(0,1);

# %% [markdown]
# Norethisterone is a progestin used in birth control pills, so perhaps not surprising that it is differentially active in the HELA cell line. Though unclear why it doesn't have a similar response pattern in the breast cancer lines.
